# %% [markdown]
# <h2><center>DATA MANIPULATION WITH PANDAS</h2>

# %% [markdown]
# <h4>To perform data manipulation operations such as selecting, filtering, sorting, updating, and creating new columns using the Pandas
# library on students dataset.</h4>

# %% [markdown]
# <h2> 1: Install and Import Pandas Library using commands:</h2>

# %%
import pandas as pd

# %% [markdown]
# <h2> 2: Load your new dataset</h2>

# %%
thrilokya_128 = pd.read_csv('employee_performance_dataset.csv')

# %%
# Reading the head of the Dataset
thrilokya_128.head(5)

# %%
# Set Index for the DataFrame (unique identifier)
df = df.set_index('Employee_ID')

# %% [markdown]
# <h2> 3: Set Index and Check Dataset Information</h2>

# %%
# Reading the head of the Dataset
thrilokya_128.head(5)

# %%
# Information about the DataFrame
thrilokya_128.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Employee_ID             100 non-null    int64
#  1   Employee_Name           100 non-null    object
#  2   Age                     100 non-null    int64
#  3   Department              100 non-null    object
#  4   City                    100 non-null    object
#  5   Salary                  100 non-null    int64
#  6   Experience_Years        100 non-null    int64
#  7   Jan_Score               100 non-null    int64
#  8   Feb_Score               100 non-null    int64
#  9   Mar_Score               100 non-null    int64
#  10  Apr_Score               100 non-null    int64
#  11  May_Score               100 non-null    int64
#  12  Jun_Score               100 non-null    int64
#  13  Attendance              100 non-null    float64
# ...

# %% [markdown]
# <h2>4: Selecting Columns and Rows</h2>

# %%
# Selecting a single column
thrilokya_128['Employee_Name']
# Out:
# 0        Aarav
# 1        Meera
# 2        Rohan
# 3        Anika
# 4        Kabir
#         ...
# 95       Ira_4
# 96    Vihaan_4
# 97      Tara_4
# 98    Aditya_4
# 99     Nisha_4
# Name: Employee_Name, Length: 100, dtype: object

# %%
# Selecting multiple columns
thrilokya_128[['Employee_Name', 'Department', 'City']].head(3)
# Out:
#   Employee_Name Department       City
# 0         Aarav         IT  Bengaluru
# 1         Meera         HR    Chennai
# 2         Rohan         HR     Mumbai

# %%
# Select row using position-based indexing
thrilokya_128.iloc[1]
# Out:
# Employee_ID                     5002
# Employee_Name                  Meera
# Age                               24
# Department                        HR
# City                         Chennai
# Salary                         65118
# Experience_Years                  10
# Jan_Score                         96
# Feb_Score                         89
# Mar_Score                         81
# Apr_Score                         69
# May_Score                         83
# Jun_Score                         92
# Attendance                     78.57
# Current_Project           Mobile App
# Work_Mode                     Hybrid
# Total_Score                      510
# Performance_Percentage          85.0
# Name: 1, dtype: object

# %%
# Select row using label-based indexing
thrilokya_128.loc[5003]
# Out:
# Employee_Name                      Rohan
# Age                                   22
# Department                            HR
# City                              Mumbai
# Salary                             54298
# Experience_Years                       5
# Jan_Score                             61
# Feb_Score                             60
# Mar_Score                             79
# Apr_Score                             61
# May_Score                             77
# Jun_Score                             77
# Attendance                         81.34
# Current_Project           Data Migration
# Work_Mode                         Remote
# Total_Score                          415
# Performance_Percentage             69.17
# Name: 5003, dtype: object

# %% [markdown]
# <h2>5: Manipulating Data Based on Columns</h2>

# %%
thrilokya_128.head(2)
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5002                Meera   24         HR    Chennai   65118
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5002                       10         96         89         81         69
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# 5001                82         57       81.00  Website Revamp    Office
# 5002                83         92       78.57      Mobile App    Hybrid
#
#              Total_Score  Performance_Percentage
# Employee_ID
# 5001                 478                   79.67
# 5002                 510                   85.00

# %%
# Rounding Attendance to 2 decimal places
thrilokya_128['Attendance'] = thrilokya_128['Attendance'].round(1)

thrilokya_128.head(2)
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5002                Meera   24         HR    Chennai   65118
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5002                       10         96         89         81         69
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# 5001                82         57        81.0  Website Revamp    Office
# 5002                83         92        78.6      Mobile App    Hybrid
#
#              Total_Score  Performance_Percentage
# Employee_ID
# 5001                 478                   79.67
# 5002                 510                   85.00

# %% [markdown]
# <h2>6: Creating New Columns</h2>

# %%
# List of monthly performance columns
months_128 = [
    'Jan_Score',
    'Feb_Score',
    'Mar_Score',
    'Apr_Score',
    'May_Score',
    'Jun_Score'
]

# %%
# Calculate Total Score
thrilokya_128['Total_Score'] = thrilokya_128[months_128].sum(axis=1)

thrilokya_128.head(2)
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5002                Meera   24         HR    Chennai   65118
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5002                       10         96         89         81         69
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# 5001                82         57        81.0  Website Revamp    Office
# 5002                83         92        78.6      Mobile App    Hybrid
#
#              Total_Score  Performance_Percentage
# Employee_ID
# 5001                 478                   79.67
# 5002                 510                   85.00

# %%
# Calculate Performance Percentage
thrilokya_128['Performance_Percentage'] = ( thrilokya_128['Total_Score'] / 600) * 100

# %%
thrilokya_128.head(2)
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5002                Meera   24         HR    Chennai   65118
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5002                       10         96         89         81         69
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# 5001                82         57        81.0  Website Revamp    Office
# 5002                83         92        78.6      Mobile App    Hybrid
#
#              Total_Score  Performance_Percentage
# Employee_ID
# 5001                 478               79.666667
# 5002                 510               85.000000

# %%
# Round Performance Percentage to 2 decimal places
thrilokya_128['Performance_Percentage'] = (thrilokya_128['Performance_Percentage'].round(1))
thrilokya_128.head(2)
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5002                Meera   24         HR    Chennai   65118
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5002                       10         96         89         81         69
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# 5001                82         57        81.0  Website Revamp    Office
# 5002                83         92        78.6      Mobile App    Hybrid
#
#              Total_Score  Performance_Percentage
# Employee_ID
# 5001                 478                    79.7
# 5002                 510                    85.0

# %% [markdown]
# <h2>7: Conditional Filtering</h2>

# %%
# Employees with Attendance greater than 90%
thrilokya_128[thrilokya_128['Attendance'] > 90].head(5)
# Out:
#             Employee_Name  Age Department           City  Salary  \
# Employee_ID
# 5004                Anika   30         IT          Delhi   67142
# 5006                  Ira   33         HR           Pune   55283
# 5007               Vihaan   29         HR          Delhi   56867
# 5008                 Tara   32  Marketing      Bengaluru   36337
# 5009               Aditya   26    Finance  Visakhapatnam   48162
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5004                        2         60         90         73         95
# 5006                        4         98         96         59         93
# 5007                        5         90         69         98         75
# 5008                        4         75         68         96         86
# 5009                       12         92         82         92         80
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %%
# Performance greater than 80% AND Attendance less than 90%
thrilokya_128[
    (thrilokya_128['Performance_Percentage'] > 80) &
    (thrilokya_128['Attendance'] < 90)
].head(5)
# Out:
#             Employee_Name  Age  Department       City  Salary  \
# Employee_ID
# 5002                Meera   24          HR    Chennai   65118
# 5025                 Neil   40  Operations  Hyderabad   72591
# 5029                Rahul   39          HR  Bengaluru   50465
# 5035              Kabir_2   29          IT    Chennai   58113
# 5037             Vihaan_2   38          IT     Mumbai   90949
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5002                       10         96         89         81         69
# 5025                        2         91         88         75         71
# 5029                       10         68         98         95         71
# 5035                        6         72         77         96         87
# 5037                       10         82         55         88         89
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %%
# Employees from Hyderabad OR Chennai
thrilokya_128[(thrilokya_128['City'] == 'Hyderabad') |(thrilokya_128['City'] == 'Chennai')].head()
# Out:
#             Employee_Name  Age  Department       City  Salary  \
# Employee_ID
# 5002                Meera   24          HR    Chennai   65118
# 5013              Reyansh   38  Operations    Chennai   42016
# 5014                 Diya   33     Finance    Chennai   35796
# 5017                 Yash   22          IT  Hyderabad   47003
# 5023               Ritvik   31          HR  Hyderabad   69957
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5002                       10         96         89         81         69
# 5013                        6         88         55         93         75
# 5014                        4         60         86         59         89
# 5017                        2         59         87         70         72
# 5023                       12         75         58         58         92
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %%
# Employees who are 25 years old AND belong to IT
thrilokya_128[(thrilokya_128['Age'] == 25) & (thrilokya_128['Department'] == 'IT')]
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5027                Varun   25         IT      Kochi   45969
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5027                        9         59         70         78         73
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# 5001                82         57        81.0  Website Revamp    Office
# 5027                65         83        83.7  Data Migration    Remote
#
#              Total_Score  Performance_Percentage
# Employee_ID
# 5001                 478                    79.7
# 5027                 428                    71.3

# %%
# Employees aged 25 OR 30 and belonging to IT
thrilokya_128[((thrilokya_128['Age'] == 25) |(thrilokya_128['Age'] == 30)) &(thrilokya_128['Department'] == 'IT')
]
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5004                Anika   30         IT      Delhi   67142
# 5027                Varun   25         IT      Kochi   45969
# 5081                Dev_3   30         IT  Bengaluru   79582
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5004                        2         60         90         73         95
# 5027                        9         59         70         78         73
# 5081                        5         97         86         64         83
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# 5001                82         57        81.0  Website Revamp    Office
# 5004                94         78        98.9   Cloud Upgrade    Remote
# ...

# %% [markdown]
# <h2>8: Filtering Using .isin()</h2>

# %%
# Employees from multiple departments
thrilokya_128[thrilokya_128['Department'].isin(['IT', 'Finance', 'Marketing'])].head()
# Out:
#             Employee_Name  Age Department           City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT      Bengaluru   48049
# 5004                Anika   30         IT          Delhi   67142
# 5008                 Tara   32  Marketing      Bengaluru   36337
# 5009               Aditya   26    Finance  Visakhapatnam   48162
# 5010                Nisha   38  Marketing     Vijayawada   81530
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5004                        2         60         90         73         95
# 5008                        4         75         68         96         86
# 5009                       12         92         82         92         80
# 5010                        1         95         65         98         82
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %%
# Employees from multiple cities
thrilokya_128[thrilokya_128['City'].isin(['Hyderabad', 'Bengaluru', 'Pune'])].head()
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5006                  Ira   33         HR       Pune   55283
# 5008                 Tara   32  Marketing  Bengaluru   36337
# 5017                 Yash   22         IT  Hyderabad   47003
# 5023               Ritvik   31         HR  Hyderabad   69957
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5006                        4         98         96         59         93
# 5008                        4         75         68         96         86
# 5017                        2         59         87         70         72
# 5023                       12         75         58         58         92
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %%
# Employees with selected ages
thrilokya_128[thrilokya_128['Age'].isin([24, 25, 30])].head()
# Out:
#             Employee_Name  Age Department       City  Salary  \
# Employee_ID
# 5001                Aarav   25         IT  Bengaluru   48049
# 5002                Meera   24         HR    Chennai   65118
# 5004                Anika   30         IT      Delhi   67142
# 5012                Kavya   25    Finance     Mumbai   42365
# 5027                Varun   25         IT      Kochi   45969
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5001                        4         98         89         60         92
# 5002                       10         96         89         81         69
# 5004                        2         60         90         73         95
# 5012                        8         71         87         66         87
# 5027                        9         59         70         78         73
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %% [markdown]
# <h2>9: Sorting the Table</h2>

# %%
# Sorting based on Age in descending order
thrilokya_128.sort_values('Age',ascending = False).head()
# Out:
#             Employee_Name  Age  Department       City  Salary  \
# Employee_ID
# 5055               Neil_2   40       Sales     Mumbai   57995
# 5056             Shreya_2   40          IT       Pune   66913
# 5025                 Neil   40  Operations  Hyderabad   72591
# 5072              Kavya_3   40     Finance      Delhi   40149
# 5094              Anika_4   39     Finance      Kochi   64885
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5055                       12         95         70         61         74
# 5056                        7         87         96         76         55
# 5025                        2         91         88         75         71
# 5072                        8         80         72         87         89
# 5094                       15         71         85         73         76
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %%
# Sorting based on Salary in ascending order
thrilokya_128.sort_values('Salary',ascending=True).head()
# Out:
#             Employee_Name  Age  Department        City  Salary  \
# Employee_ID
# 5028                 Anvi   31  Operations       Kochi   32512
# 5093              Rohan_4   23     Finance       Delhi   34186
# 5005                Kabir   28       Sales  Vijayawada   35003
# 5014                 Diya   33     Finance     Chennai   35796
# 5008                 Tara   32   Marketing   Bengaluru   36337
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5028                       11         97         61         63         71
# 5093                       10         60         73         75         81
# 5005                       11         60         69         61         79
# 5014                        4         60         86         59         89
# 5008                        4         75         68         96         86
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %%
# Sorting based on Age and Performance Percentage
thrilokya_128.sort_values(['Age', 'Performance_Percentage'],ascending=False).head()
# Out:
#             Employee_Name  Age  Department       City  Salary  \
# Employee_ID
# 5072              Kavya_3   40     Finance      Delhi   40149
# 5055               Neil_2   40       Sales     Mumbai   57995
# 5025                 Neil   40  Operations  Hyderabad   72591
# 5056             Shreya_2   40          IT       Pune   66913
# 5029                Rahul   39          HR  Bengaluru   50465
#
#              Experience_Years  Jan_Score  Feb_Score  Mar_Score  Apr_Score  \
# Employee_ID
# 5072                        8         80         72         87         89
# 5055                       12         95         70         61         74
# 5025                        2         91         88         75         71
# 5056                        7         87         96         76         55
# 5029                       10         68         98         95         71
#
#              May_Score  Jun_Score  Attendance Current_Project Work_Mode  \
# Employee_ID
# ...

# %% [markdown]
# <h2>10: Updating Data</h2>

# %%
# Updating Hyderabad as HYD
thrilokya_128['City'] = thrilokya_128['City'].replace(['Hyderabad'],['HYD'])

# %%
thrilokya_128[thrilokya_128['City'] == 'HYD'].head(2)
# Out:
#             Employee_Name  Age Department City  Salary  Experience_Years  \
# Employee_ID
# 5017                 Yash   22         IT  HYD   47003                 2
# 5023               Ritvik   31         HR  HYD   69957                12
#
#              Jan_Score  Feb_Score  Mar_Score  Apr_Score  May_Score  Jun_Score  \
# Employee_ID
# 5017                59         87         70         72         97         86
# 5023                75         58         58         92         85         87
#
#              Attendance Current_Project Work_Mode  Total_Score  \
# Employee_ID
# 5017               97.5  Data Migration    Office          471
# 5023               89.7       Analytics    Remote          455
#
#              Performance_Percentage
# Employee_ID
# 5017                           78.5
# 5023                           75.8

# %%
# Updating salary of Employee 5003
thrilokya_128.loc[5003, 'Salary'] = 60000

# %%
print(thrilokya_128.loc[5003, 'Salary'])
# Out:
# 60000

# %% [markdown]
# <h2>11: Changing Column Names</h2>

# %%
# Changing column names
thrilokya_128 = thrilokya_128.rename(columns={
        'Employee_Name': 'Name',
        'Experience_Years': 'Experience',
        'Performance_Percentage': 'Performance'
    }
)

# %%
thrilokya_128.head(1)
# Out:
#               Name  Age Department       City  Salary  Experience  Jan_Score  \
# Employee_ID
# 5001         Aarav   25         IT  Bengaluru   48049           4         98
#
#              Feb_Score  Mar_Score  Apr_Score  May_Score  Jun_Score  \
# Employee_ID
# 5001                89         60         92         82         57
#
#              Attendance Current_Project Work_Mode  Total_Score  Performance
# Employee_ID
# 5001               81.0  Website Revamp    Office          478         79.7

# %% [markdown]
# <h2> 12: Final Dataset</h2>

# %% [markdown]
# thrilokya_128

# %% [markdown]
# <h2>RESULT:</h2>
# <h4>By using the Pandas library, various data manipulation techniques such as selecting specific rows and columns, rounding and updating values,
# conditional filtering, renaming columns were successfully implemented on the student dataset.</h4>

# %% [markdown]
# <h2>Conclusion</h2>
# <h4>Thus, various data manipulation operations were successfully performed using the
# Pandas library. Data was selected, filtered, sorted, updated, and new columns were
# created. The experiment demonstrated how Pandas can be used to efficiently manipulate
# and work with structured datasets.</h4>
